# %% [markdown]
# ##### Introduction to Jupyter NoteBook

# %% [markdown]
# 1. Web Scraping
# 2. Extract data from Website
# 3. Write the data to Excel
# 4. Write the data to SQL
# 5. Plot Graph

# %%
a= 'python'

# %%
print(a)
# Out:
# python

# %%
a= [1,'a1',2,'sad',[1,2,3]]

# %%
type(a)
# Out:
# list

# %%
for i in a :
    print(i)
# Out:
# 1
# a1
# 2
# sad
# [1, 2, 3]

# %%
len(a)
# Out:
# 5

# %%
a[0]

# %% [markdown]
# Introduction of pandas

# %%
import pandas as pd

# %%
pd.read_excel("../data/accident_data.xlsx")
# Out:
#        accident_id  accident_month  accident_year  accident_cost  human_admit  \
# 0                1               7             14     15000000.0            0
# 1                2               7             14     15000000.0            0
# 2                3               8             14        59000.0            1
# 3                4               7             13      4000000.0            0
# 4                5               7             13      4000000.0            0
# 5                6               7             13            0.0            0
# 6                7              10             12      5000000.0            0
# 7                8              10             12       500000.0            0
# 8                9              10             12     15000000.0            0
# 9               10              10             12     15000000.0            0
# 10              11              10             12     15000000.0            0
# ...
