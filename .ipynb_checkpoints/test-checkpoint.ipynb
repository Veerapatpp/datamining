# %%
import pandas as pd
import seaborn as sns
import warnings

# %%
data = pd.read_excel('AQI.xlsx')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
a = data.groupby('Risk')
a['Risk'].count()
# Out:
# Risk
# Good                              21994
# Moderate                           1550
# Unhealthy for sensitive groups        5
# Name: Risk, dtype: int64

# %%
data
# Out:
#        Year  Month  Day  UTC Hour  dayofweek dayofweek.1  dayofyear  PM2.5  \
# 0      2016      3    3         8          5         Thu         63   62.9
# 1      2016      3    3         9          5         Thu         63   62.9
# 2      2016      3    3        10          5         Thu         63   55.5
# 3      2016      3    3        11          5         Thu         63   55.5
# 4      2016      3    3        12          5         Thu         63   47.9
# 5      2016      3    3        13          5         Thu         63   43.6
# 6      2016      3    3        14          5         Thu         63   28.6
# 7      2016      3    3        15          5         Thu         63   33.6
# 8      2016      3    3        16          5         Thu         63   34.8
# 9      2016      3    3        17          5         Thu         63   31.3
# 10     2016      3    3        19          5         Thu         63   42.1
# 11     2016      3    3        20          5         Thu         63   38.6
# 12     2016      3    3        21          5         Thu         63   45.5
# 13     2016      3    3        22          5         Thu         63   49.9
# 14     2016      3    3        23          5         Thu         63   44.1
# 15     2016      3    4         0          6         Fri         64   42.1
# 16     2016      3    4         1          6         Fri         64   43.1
# 17     2016      3    4         2          6         Fri         64   44.8
# 18     2016      3    4         3          6         Fri         64   37.5
# 19     2016      3    4         4          6         Fri         64   39.6
# 20     2016      3    4         5          6         Fri         64   46.0
# 21     2016      3    4         6          6         Fri         64   43.8
# 22     2016      3    4         7          6         Fri         64   36.6
# 23     2016      3    4         8          6         Fri         64   34.2
# 24     2016      3    4         9          6         Fri         64   35.0
# 25     2016      3    4        10          6         Fri         64   30.0
# 26     2016      3    4        11          6         Fri         64   25.6
# 27     2016      3    4        12          6         Fri         64   32.1
# 28     2016      3    4        13          6         Fri         64   24.4
# 29     2016      3    4        14          6         Fri         64   32.8
# ...     ...    ...  ...       ...        ...         ...        ...    ...
# 23519  2019      1   26        18          7         Sat         26   56.0
# 23520  2019      1   26        19          7         Sat         26   57.8
# 23521  2019      1   26        20          7         Sat         26   65.2
# 23522  2019      1   26        21          7         Sat         26   65.5
# 23523  2019      1   26        22          7         Sat         26   62.5
# 23524  2019      1   26        23          7         Sat         26   54.8
# 23525  2019      1   27         2          1         Sun         27   39.6
# 23526  2019      1   27         3          1         Sun         27   36.8
# 23527  2019      1   27         4          1         Sun         27   38.2
# 23528  2019      1   27         5          1         Sun         27   33.9
# 23529  2019      1   27         7          1         Sun         27   31.8
# 23530  2019      1   27         8          1         Sun         27   31.1
# 23531  2019      1   27         9          1         Sun         27   30.5
# 23532  2019      1   27        10          1         Sun         27   33.8
# 23533  2019      1   27        11          1         Sun         27   36.5
# 23534  2019      1   27        12          1         Sun         27   37.9
# 23535  2019      1   27        13          1         Sun         27   39.6
# 23536  2019      1   27        14          1         Sun         27   40.4
# 23537  2019      1   27        15          1         Sun         27   44.7
# 23538  2019      1   27        16          1         Sun         27   47.3
# 23539  2019      1   27        17          1         Sun         27   50.6
# 23540  2019      1   27        18          1         Sun         27   52.0
# 23541  2019      1   27        19          1         Sun         27   55.5
# 23542  2019      1   27        20          1         Sun         27   56.5
# 23543  2019      1   27        21          1         Sun         27   59.6
# 23544  2019      1   27        22          1         Sun         27   62.7
# 23545  2019      1   27        23          1         Sun         27   62.4
# 23546  2019      1   28         0          2         Mon         28   58.1
# 23547  2019      1   28         1          2         Mon         28   54.2
# 23548  2019      1   28         2          2         Mon         28   53.5
#
#            Risk
# 0      Moderate
# 1      Moderate
# 2      Moderate
# 3      Moderate
# 4          Good
# 5          Good
# 6          Good
# 7          Good
# 8          Good
# 9          Good
# 10         Good
# 11         Good
# 12         Good
# 13         Good
# 14         Good
# 15         Good
# 16         Good
# 17         Good
# 18         Good
# 19         Good
# 20         Good
# 21         Good
# 22         Good
# 23         Good
# 24         Good
# 25         Good
# 26         Good
# 27         Good
# 28         Good
# 29         Good
# ...         ...
# 23519  Moderate
# 23520  Moderate
# 23521  Moderate
# 23522  Moderate
# 23523  Moderate
# 23524  Moderate
# 23525      Good
# 23526      Good
# 23527      Good
# 23528      Good
# 23529      Good
# 23530      Good
# 23531      Good
# 23532      Good
# 23533      Good
# 23534      Good
# 23535      Good
# 23536      Good
# 23537      Good
# 23538      Good
# 23539  Moderate
# 23540  Moderate
# 23541  Moderate
# 23542  Moderate
# 23543  Moderate
# 23544  Moderate
# 23545  Moderate
# 23546  Moderate
# 23547  Moderate
# 23548  Moderate
#
# [23549 rows x 9 columns]

# %%
data['season'] = pd.cut(data['Month'],bins=[0,2,5,10,12],right=True,labels=['Winters','Summer','Rainy','Winter'])

# %%
data['season'].replace({'Winters':'Winter'}, inplace=True)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-29a79790751a> in <module>
# ----> 1 data.unique()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
fi = plt.figure(figsize=(15,5))
axes = fi.add_subplot(121)
sns.distplot(data[data['Risk']=='Moderate' ]['Month'],color='pink')
axes = fi.add_subplot(122)
sns.distplot(data[data['Risk']=='Good']['Month'],color='green')
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
data[['Risk']].descrie()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-8ac26fca5ea7> in <module>
# ----> 1 data[['Risk']].descrie()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'descrie'

# %%
data['Risk'].unique()
# Out:
# array(['Moderate', 'Good', 'Unhealthy for sensitive groups'], dtype=object)

# %%
data['Risk'].replace({'Unhealthy for sensitive groups':'Unhealthy'}, inplace=True)

# %%
fi = plt.figure(figsize=(15,5))
axes = fi.add_subplot(122)
sns.distplot(data[data['Risk']=='Unhealthy']['Month'],color='blue')

# %%
sns.lmplot(x='dayofyear',y='PM2.5',data=data,hue='Risk',fit_reg=False,height=10,aspect=1)

# %%
fi = plt.figure(figsize=(15,10))
sns.set(style="whitegrid")

sns.lineplot(data=data,x='Month',y='PM2.5',hue = 'Year')

# %%
plt.plot( 'Month', 'PM2.5', data=data, markerfacecolor='blue', color='skyblue', linewidth=4)
plt.plot( 'Month', 'season', data=data, marker='', color='olive', linewidth=2)
plt.plot( 'Month', 'PM2.5', data=data, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")
plt.legend()

# %%
plt.plot()
