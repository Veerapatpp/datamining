# %%
import pandas as pd

# %%
data = pd.read_excel('../data/IMDB.xlsx')

# %%
data
# Out:
#                 color       director_name  num_critic_for_reviews  duration  \
# 0               Color       James Cameron                   723.0     178.0
# 1               Color      Gore Verbinski                   302.0     169.0
# 2               Color          Sam Mendes                   602.0     148.0
# 3               Color   Christopher Nolan                   813.0     164.0
# 4               Color      Andrew Stanton                   462.0     132.0
# 5               Color           Sam Raimi                   392.0     156.0
# 6               Color         Joss Whedon                   635.0     141.0
# 7               Color         Zack Snyder                   673.0     183.0
# 8               Color        Bryan Singer                   434.0     169.0
# 9               Color        Marc Forster                   403.0     106.0
# 10              Color      Gore Verbinski                   313.0     151.0
# ...

# %%
data.color
# Out:
# 0                 Color
# 1                 Color
# 2                 Color
# 3                 Color
# 4                 Color
# 5                 Color
# 6                 Color
# 7                 Color
# 8                 Color
# 9                 Color
# 10                Color
# 11                Color
# 12                Color
# 13                Color
# 14                Color
# 15                Color
# 16                Color
# 17                Color
# 18                Color
# 19                Color
# 20                Color
# 21                Color
# 22                Color
# 23                Color
# 24                Color
# 25                Color
# 26                Color
# 27                Color
# 28                Color
# 29                Color
#              ...
# 5009              Color
# 5010    Black and White
# 5011              Color
# 5012              Color
# 5013              Color
# 5014              Color
# 5015              Color
# ...

# %%
data.color[-5:]
# Out:
# 5034              Color
# 5035    Black and White
# 5036              Color
# 5037              Color
# 5038              Color
# Name: color, dtype: object

# %%
data[['color']].head()
# Out:
#    color
# 0  Color
# 1  Color
# 2  Color
# 3  Color
# 4  Color

# %%
data.loc[[10,20,30,40],['color','movie_title','gross']].sort_values(by='gross',ascending = False)
# Out:
#     color                                        movie_title        gross
# 10  Color        Pirates of the Caribbean: Dead Man's Chest   423032628.0
# 20  Color                        Captain America: Civil War   407197282.0
# 40  Color  Indiana Jones and the Kingdom of the Crystal S...  317011114.0
# 30  Color                                      TRON: Legacy   172051787.0

# %%
data.loc['budget']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1789                 if not ax.contains(key):
# -> 1790                     error()
#    1791             except TypeError as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#
# KeyError: 'the label [budget] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-0f5c325a03f1> in <module>()
# ----> 1 data.loc['budget']
#
# ...

# %%
data.loc['color','movie_title','gross'].sort_values(by='gross',ascending = False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1789                 if not ax.contains(key):
# -> 1790                     error()
#    1791             except TypeError as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#
# KeyError: 'the label [color] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-e544ef15d972> in <module>()
# ----> 1 data.loc['color','movie_title','gross'].sort_values(by='gross',ascending = False)
#
# ...

# %%
data[['movie_title','gross']].sort_values(by='gross',ascending =False).head()
# Out:
#           movie_title        gross
# 0             Avatar   760505847.0
# 3403         Titanic   658672302.0
# 22    Jurassic World   652177271.0
# 411     The Avengers   623279547.0
# 14      The Avengers   623279547.0

# %%
data.language.unique()
# Out:
# array(['English', 'Japanese', 'Spanish', 'Mandarin', 'Filipino', 'French',
#        'Maya', 'Telugu', 'Russian', 'Cantonese', 'German', 'Swedish',
#        'Korean', 'Polish', 'Hindi', 'Thai', 'Arabic', 'Chinese', nan,
#        'Portuguese', 'Danish', 'Indonesian', 'Italian', 'Mongolian',
#        'None', 'Aboriginal', 'Dzongkha', 'Hebrew', 'Icelandic', 'Czech',
#        'Kannada', 'Norwegian', 'Dutch', 'Tamil', 'Urdu', 'Zulu', 'Kazakh',
#        'Bosnian', 'Hungarian', 'Persian', 'Greek', 'Aramaic', 'Dari',
#        'Panjabi', 'Vietnamese', 'Romanian', 'Slovenian', 'Swahili'],
#       dtype=object)

# %%
data.language.value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'laguage'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-2755f87aafc7> in <module>()
#       1 data.language.value_counts()
# ...

# %%
data[data['language']=='Thai'][['movie_title','gross','director_name']]
# Out:
#                     movie_title       gross        director_name
# 959   The Legend of Suriyothai     454255.0  Chatrichalerm Yukol
# 1014             The Protector   11905519.0      Prachya Pinkaew
# 4596                 Ong-bak 2     102055.0             Tony Jaa

# %%
% matplotlib inline
import  matplotlib.pyplot as plt

# %%
data[data['language']=='Thai'][['movie_title','gross','director_name']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001AD9D4684A8>]],
#       dtype=object)

# %%
data[data['gross']<200000][['gross']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001AD9D5D0128>]],
#       dtype=object)

# %%
data['imdb_score'].hist()

# %% [markdown]
# ## Bining ibmd_score to 'bad','med','good'

# %%
data['imdb_rate'] = pd.cut(data['imdb_score'],bins=[0,6,7,10],right=True,labels=['Bad','Med','Good'])

# %%
data['imdb_rate'].value_counts()
# Out:
# Med     1864
# Good    1592
# Bad     1583
# Name: imdb_rate, dtype: int64

# %%
import seaborn as sns

# %%
sns.lmplot(x='imdb_score',y='gross',data=data,hue='imdb_rate',fit_reg=False)

# %%
sns.lmplot(x='imdb_score',y='budget',data=data,hue='imdb_rate',fit_reg=False)

# %%
data_corr= data.corr()

# %%
import numpy as np
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)
cax = ax.matshow(data_corr, vmin=-1, vmax=1)
feature_names =list(data_corr.columns)
fig.colorbar(cax)
ticks = np.arange(0,len(data_corr.columns),1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(feature_names)
ax.set_yticklabels(feature_names)
plt.xticks(rotation=90)
plt.show()

# %%
data_corr.head()
# Out:
#                          num_critic_for_reviews  duration  \
# num_critic_for_reviews                 1.000000  0.258477
# duration                               0.258477  1.000000
# director_facebook_likes                0.180626  0.173355
# actor_3_facebook_likes                 0.271602  0.123545
# actor_1_facebook_likes                 0.189929  0.088246
#
#                          director_facebook_likes  actor_3_facebook_likes  \
# num_critic_for_reviews                  0.180626                0.271602
# duration                                0.173355                0.123545
# director_facebook_likes                 1.000000                0.120178
# actor_3_facebook_likes                  0.120178                1.000000
# actor_1_facebook_likes                  0.090654                0.249900
#
#                          actor_1_facebook_likes     gross  num_voted_users  \
# num_critic_for_reviews                 0.189929  0.480555         0.624888
# ...

# %%
a = ('English','Thai')
data_prep = data[(data['color']=='Color') &( (data['language']=='Thai') | (data['language']=='English'))]

# %%
data_prep.language.value_counts()
# Out:
# English    4507
# Thai          3
# Name: language, dtype: int64

# %%
data_prep = data_prep[pd.notnull(data_prep['gross'])]

# %%
data_prep
# Out:
#       color       director_name  num_critic_for_reviews  duration  \
# 0     Color       James Cameron                   723.0     178.0
# 1     Color      Gore Verbinski                   302.0     169.0
# 2     Color          Sam Mendes                   602.0     148.0
# 3     Color   Christopher Nolan                   813.0     164.0
# 4     Color      Andrew Stanton                   462.0     132.0
# 5     Color           Sam Raimi                   392.0     156.0
# 6     Color         Joss Whedon                   635.0     141.0
# 7     Color         Zack Snyder                   673.0     183.0
# 8     Color        Bryan Singer                   434.0     169.0
# 9     Color        Marc Forster                   403.0     106.0
# 10    Color      Gore Verbinski                   313.0     151.0
# 11    Color      Gore Verbinski                   450.0     150.0
# 12    Color         Zack Snyder                   733.0     143.0
# ...

# %%
data_prep = data_prep[pd.notnull(data_prep['director_name'])]
data_prep = data_prep[pd.notnull(data_prep['actor_1_name'])]
data_prep = data_prep[pd.notnull(data_prep['actor_2_name'])]
data_prep = data_prep[pd.notnull(data_prep['actor_3_name'])]
data_prep = data_prep[pd.notnull(data_prep['title_year'])]
data_prep = data_prep[pd.notnull(data_prep['imdb_rate'])]

# %%
data.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'movie_imdb_link',
#        'num_user_for_reviews', 'language', 'country', 'content_rating',
#        'budget', 'title_year', 'actor_2_facebook_likes', 'imdb_score',
#        'movie_facebook_likes', 'imdb_rate'],
#       dtype='object')

# %%
data_prep
# Out:
#       color       director_name  num_critic_for_reviews  duration  \
# 0     Color       James Cameron                   723.0     178.0
# 1     Color      Gore Verbinski                   302.0     169.0
# 2     Color          Sam Mendes                   602.0     148.0
# 3     Color   Christopher Nolan                   813.0     164.0
# 4     Color      Andrew Stanton                   462.0     132.0
# 5     Color           Sam Raimi                   392.0     156.0
# 6     Color         Joss Whedon                   635.0     141.0
# 7     Color         Zack Snyder                   673.0     183.0
# 8     Color        Bryan Singer                   434.0     169.0
# 9     Color        Marc Forster                   403.0     106.0
# 10    Color      Gore Verbinski                   313.0     151.0
# 11    Color      Gore Verbinski                   450.0     150.0
# 12    Color         Zack Snyder                   733.0     143.0
# ...

# %%
data.language.unique()
# Out:
# array(['English', 'Japanese', 'Spanish', 'Mandarin', 'Filipino', 'French',
#        'Maya', 'Telugu', 'Russian', 'Cantonese', 'German', 'Swedish',
#        'Korean', 'Polish', 'Hindi', 'Thai', 'Arabic', 'Chinese', nan,
#        'Portuguese', 'Danish', 'Indonesian', 'Italian', 'Mongolian',
#        'None', 'Aboriginal', 'Dzongkha', 'Hebrew', 'Icelandic', 'Czech',
#        'Kannada', 'Norwegian', 'Dutch', 'Tamil', 'Urdu', 'Zulu', 'Kazakh',
#        'Bosnian', 'Hungarian', 'Persian', 'Greek', 'Aramaic', 'Dari',
#        'Panjabi', 'Vietnamese', 'Romanian', 'Slovenian', 'Swahili'],
#       dtype=object)

# %%
#fill null values 0 l
data_prep.isnull().sum()
# Out:
# color                        0
# director_name                0
# num_critic_for_reviews       0
# duration                     0
# director_facebook_likes      0
# actor_3_facebook_likes       0
# actor_2_name                 0
# actor_1_facebook_likes       0
# gross                        0
# genres                       0
# actor_1_name                 0
# movie_title                  0
# num_voted_users              0
# cast_total_facebook_likes    0
# actor_3_name                 0
# facenumber_in_poster         0
# movie_imdb_link              0
# num_user_for_reviews         0
# language                     0
# country                      0
# content_rating               0
# budget                       0
# title_year                   0
# actor_2_facebook_likes       0
# imdb_score                   0
# movie_facebook_likes         0
# imdb_rate                    0
# dtype: int64

# %%
#replace 0
data_prep['num_critic_for_reviews'].fillna(0,inplace=True)
# Out:
#   File "<ipython-input-126-bd453e2ba3f2>", line 2
#     data_prep['num_critic_for_reviews'].fillna(0,inplace=True)data_prep['num_critic_for_reviews'].fillna(0,inplace=True)
#                                                                       ^
# SyntaxError: invalid syntax

# %%
data_prep=data_prep.dropna()

# %%
data_prep=data_prep.drop(columns = ['movie_title','imdb_score','imdb_score','title_year'])

# %%
#decistion tree encode => number
data_prep.dtypes
# Out:
# color                          object
# director_name                  object
# num_critic_for_reviews        float64
# duration                      float64
# director_facebook_likes       float64
# actor_3_facebook_likes        float64
# actor_2_name                   object
# actor_1_facebook_likes        float64
# gross                         float64
# genres                         object
# actor_1_name                   object
# num_voted_users                 int64
# cast_total_facebook_likes       int64
# actor_3_name                   object
# facenumber_in_poster          float64
# movie_imdb_link                object
# num_user_for_reviews          float64
# language                       object
# country                        object
# content_rating                 object
# budget                        float64
# actor_2_facebook_likes        float64
# movie_facebook_likes            int64
# imdb_rate                    category
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb_make =LabelEncoder()
data_prep['director_name_code'] = lb_make.fit_transform(data_prep['director_name'])
data_prep['actor_1_name_code'] = lb_make.fit_transform(data_prep['actor_1_name'])
data_prep['actor_2_name_code'] = lb_make.fit_transform(data_prep['actor_2_name'])
data_prep['actor_3_name_code'] = lb_make.fit_transform(data_prep['actor_3_name'])
data_prep['country_code'] = lb_make.fit_transform(data_prep['country'])
data_prep['genres_code'] = lb_make.fit_transform(data_prep['genres'])
data_prep['content_rating_code'] = lb_make.fit_transform(data_prep['content_rating'])

# %%
data_prep=data_prep.drop(columns = ['director_name','actor_1_name','actor_2_name','actor_3_name','country','genres','content_rating','color'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-145-710628589dbf> in <module>()
# ----> 1 data_prep=data_prep.drop(columns = ['director_name','actor_1_name','actor_2_name','actor_3_name','country','genres','content_rating','color'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3692                                            index=index, columns=columns,
#    3693                                            level=level, inplace=inplace,
# -> 3694                                            errors=errors)
#    3695
#    3696     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3106         for axis, labels in axes.items():
# ...

# %%
data_prep=data_prep.drop(columns = ['color'])

# %%
data_prep=data_prep.drop(columns = ['movie_imdb_link','language'])

# %%
data_prep=data_prep.drop(columns = ['movie_imdb_link','language'])

# %%
data_prep.dtypes
# Out:
# num_critic_for_reviews        float64
# duration                      float64
# director_facebook_likes       float64
# actor_3_facebook_likes        float64
# actor_1_facebook_likes        float64
# gross                         float64
# num_voted_users                 int64
# cast_total_facebook_likes       int64
# facenumber_in_poster          float64
# num_user_for_reviews          float64
# budget                        float64
# actor_2_facebook_likes        float64
# movie_facebook_likes            int64
# imdb_rate                    category
# director_name_code              int64
# actor_1_name_code               int64
# actor_2_name_code               int64
# actor_3_name_code               int64
# country_code                    int64
# genres_code                     int64
# content_rating_code             int64
# dtype: object

# %%
x_train = data_prep.drop(columns=['imdb_rate'])[:-1000]
#target attribute
y_train = data_prep['imdb_rate'][:-1000]

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()

# %%
cld_DT = clf.fit(x_train,y_train)

# %%
cld_DT
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
