# %%
import pandas as pd

# %%
data = pd.read_csv("result.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x85 in position 14: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-51-ff2bbd73a625> in <module>()
# ----> 1 data = pd.read_csv("result.csv")
#
# ...

# %%
data = data.drop(columns=['title'])

# %%
test = data

# %%
test
# Out:
#           year                  Team    A   D   F  GD   L   P  Pos  Pts   W  \
# 0    2016/2017               Chelsea   33   3  85  52   5  38    1   93  30
# 1    2016/2017    Tottenham Hotspurs   26   8  86  60   4  38    2   86  26
# 2    2016/2017       Manchester City   39   9  80  41   6  38    3   78  23
# 3    2016/2017             Liverpool   42  10  78  36   6  38    4   76  22
# 4    2016/2017               Arsenal   44   6  77  33   9  38    5   75  23
# 5    2016/2017     Manchester United   29  15  54  25   5  38    6   69  18
# 6    2016/2017               Everton   44  10  62  18  11  38    7   61  17
# 7    2016/2017           Southampton   48  10  41  -7  16  38    8   46  12
# 8    2016/2017           Bournemouth   67  10  55 -12  16  38    9   46  12
# 9    2016/2017  West Bromwich Albion   51   9  43  -8  17  38   10   45  12
# 10   2016/2017       West Ham United   64   9  47 -17  17  38   11   45  12
# ...

# %%
test = test[pd.notnull(test['champion'])]

# %%
test
# Out:
#           year               Team   A   D    F  GD  L   P  Pos  Pts   W  \
# 0    2016/2017            Chelsea  33   3   85  52  5  38    1   93  30
# 20   2014/2015            Chelsea  32   9   73  41  3  38    1   87  26
# 40   2013/2014    Manchester City  37   5  102  65  6  38    1   86  27
# 60   2012/2013  Manchester United  43   5   86  43  5  38    1   89  28
# 80   2011/2012    Manchester City  29   5   93  64  5  38    1   89  28
# 100  2010/2011  Manchester United  37  11   78  41  4  38    1   80  23
# 120  2009/2010            Chelsea  32   5  103  71  6  38    1   86  27
# 140  2008/2009  Manchester United  24   6   68  44  4  38    1   90  28
# 160  2007/2008  Manchester United  22   6   80  58  5  38    1   87  27
# 180  2006/2007  Manchester United  27   5   83  56  5  38    1   89  28
# 200  2005/2006            Chelsea  22   4   72  50  5  38    1   91  29
# 220  2004/2005            Chelsea  15   8   72  57  1  38    1   95  29
# ...

# %%
test['champion'].fillna(yes,inplace = "no")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-013996f04ecd> in <module>()
# ----> 1 test['champion'].fillna(yes,inplace = "no")
#
# NameError: name 'yes' is not defined

# %%
test.isnull().sum()
# Out:
# year        0
# Team        0
# A           0
# D           0
# F           0
# GD          0
# L           0
# P           0
# Pos         0
# Pts         0
# W           0
# champion    0
# dtype: int64

# %%
test
