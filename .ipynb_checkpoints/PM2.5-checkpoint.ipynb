# %%
import pandas as pd
import seaborn as sns
import warnings

# %%
data = pd.read_excel('AQI.xlsx')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
a = data.groupby('Risk')
a['Risk'].count()
# Out:
# Risk
# Good                              21994
# Moderate                           1550
# Unhealthy for sensitive groups        5
# Name: Risk, dtype: int64

# %%
data.head()
# Out:
#    Year  Month  Day  UTC Hour  dayofweek dayofweek.1  dayofyear  PM2.5  \
# 0  2016      3    3         8          5         Thu         63   62.9
# 1  2016      3    3         9          5         Thu         63   62.9
# 2  2016      3    3        10          5         Thu         63   55.5
# 3  2016      3    3        11          5         Thu         63   55.5
# 4  2016      3    3        12          5         Thu         63   47.9
#
#        Risk
# 0  Moderate
# 1  Moderate
# 2  Moderate
# 3  Moderate
# 4      Good

# %%
data['season'] = pd.cut(data['Month'],bins=[0,2,5,10,12],right=True,labels=['Winters','Summer','Rainy','Winter'])

# %%
data['season'].replace({'Winters':'Winter'}, inplace=True)

# %%
data['season'].replace({'Winters':'Winter'}, inplace=True)

# %%
fi = plt.figure(figsize=(15,5))
axes = fi.add_subplot(121)
sns.distplot(data[data['Risk']=='Moderate' ]['Month'],color='pink')
axes = fi.add_subplot(122)
sns.distplot(data[data['Risk']=='Good']['Month'],color='green')
# Out:
# C:\Users\Poom__000\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
data['Risk'].unique()
# Out:
# array(['Moderate', 'Good', 'Unhealthy for sensitive groups'], dtype=object)

# %%
data['Risk'].replace({'Unhealthy for sensitive groups':'Unhealthy'}, inplace=True)

# %%
fi = plt.figure(figsize=(15,5))
axes = fi.add_subplot(122)
sns.distplot(data[data['Risk']=='Unhealthy']['Month'],color='blue')
# Out:
# C:\Users\Poom__000\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
fi = plt.figure(figsize=(15,10))
sns.set(style="whitegrid")

sns.lineplot(data=data,x='Month',y='PM2.5',hue = 'Year')
# Out:
# C:\Users\Poom__000\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
data.head(0)
# Out:
# Empty DataFrame
# Columns: [Year, Month, Day, UTC Hour, dayofweek, dayofweek.1, dayofyear, PM2.5, Risk, season]
# Index: []

# %%
sns.catplot(x="Month", y="PM2.5",data=data, saturation=5,kind="bar", ci=None, aspect=2,hue = 'Year')

# %%
sns.catplot(x="season", y="PM2.5",data=data, saturation=10,kind="bar", ci=None, aspect=2,hue = 'Risk')

# %%
fi = plt.figure(figsize=(15,10))

sns.catplot(x="UTC Hour", y="PM2.5",data=data, saturation=5,kind="bar", ci=None, aspect=2,hue = 'Risk')

# %%
sns.catplot(x='dayofweek.1',y='PM2.5',data=data, saturation=5,kind="bar", ci=None, aspect=2,hue = 'Risk')

# %%
Thisyear = data.loc[(data['Year'] == 2018)]
fig, ax = plt.subplots(figsize=(15,10)) 
heat = Thisyear.pivot_table(values='PM2.5',index='UTC Hour',columns='dayofweek',aggfunc='mean',dropna=True)
ax.set_title('Bangkok PM2.5 This year')
sns.heatmap(heat,cmap='magma_r')
ax.set_xlabel('Day')
# Out:
# Text(0.5,66.5,'Day')

# %%
data[['dayofweek','dayofweek.1','UTC Hour','Year']]
# Out:
#        dayofweek dayofweek.1  UTC Hour  Year
# 0              5         Thu         8  2016
# 1              5         Thu         9  2016
# 2              5         Thu        10  2016
# 3              5         Thu        11  2016
# 4              5         Thu        12  2016
# 5              5         Thu        13  2016
# 6              5         Thu        14  2016
# 7              5         Thu        15  2016
# 8              5         Thu        16  2016
# 9              5         Thu        17  2016
# 10             5         Thu        19  2016
# 11             5         Thu        20  2016
# 12             5         Thu        21  2016
# 13             5         Thu        22  2016
# 14             5         Thu        23  2016
# 15             6         Fri         0  2016
# 16             6         Fri         1  2016
# 17             6         Fri         2  2016
# 18             6         Fri         3  2016
# 19             6         Fri         4  2016
# 20             6         Fri         5  2016
# 21             6         Fri         6  2016
# 22             6         Fri         7  2016
# 23             6         Fri         8  2016
# 24             6         Fri         9  2016
# 25             6         Fri        10  2016
# 26             6         Fri        11  2016
# 27             6         Fri        12  2016
# 28             6         Fri        13  2016
# 29             6         Fri        14  2016
# ...          ...         ...       ...   ...
# 23519          7         Sat        18  2019
# 23520          7         Sat        19  2019
# 23521          7         Sat        20  2019
# 23522          7         Sat        21  2019
# 23523          7         Sat        22  2019
# 23524          7         Sat        23  2019
# 23525          1         Sun         2  2019
# 23526          1         Sun         3  2019
# 23527          1         Sun         4  2019
# 23528          1         Sun         5  2019
# 23529          1         Sun         7  2019
# 23530          1         Sun         8  2019
# 23531          1         Sun         9  2019
# 23532          1         Sun        10  2019
# 23533          1         Sun        11  2019
# 23534          1         Sun        12  2019
# 23535          1         Sun        13  2019
# 23536          1         Sun        14  2019
# 23537          1         Sun        15  2019
# 23538          1         Sun        16  2019
# 23539          1         Sun        17  2019
# 23540          1         Sun        18  2019
# 23541          1         Sun        19  2019
# 23542          1         Sun        20  2019
# 23543          1         Sun        21  2019
# 23544          1         Sun        22  2019
# 23545          1         Sun        23  2019
# 23546          2         Mon         0  2019
# 23547          2         Mon         1  2019
# 23548          2         Mon         2  2019
#
# [23549 rows x 4 columns]

# %%
data.loc[(data['Risk'] == 'Unhealthy')]
# Out:
#        Year  Month  Day  UTC Hour  dayofweek dayofweek.1  dayofyear  PM2.5  \
# 8164   2017      3    3         2          6         Fri         62  115.4
# 15276  2018      1   22         1          2         Mon         22  103.4
# 15277  2018      1   22         2          2         Mon         22  100.8
# 15655  2018      2    8         3          5         Thu         39  114.3
# 15785  2018      2   14         1          4         Wed         45  104.1
#
#             Risk  season
# 8164   Unhealthy  Summer
# 15276  Unhealthy  Winter
# 15277  Unhealthy  Winter
# 15655  Unhealthy  Winter
# 15785  Unhealthy  Winter
